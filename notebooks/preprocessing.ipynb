# %% [markdown]
# ## Data Cleaning:
# Remove duplicates.
# Handle missing data.
# Normalize dates to the format YYYY-MM-DD.

# %%
import pandas as pd

# Load the data
df = pd.read_csv('../data/bank_reviews.csv')

# %%
df. describe()
df.head()
# Out:
#                                               review  rating  \
# 0  The previous version is much better than this ...       2
# 1  The good thing is its simplicity to undertake ...       3
# 2  The updated app is attractive and is working v...       4
# 3  I love this app. It's simple to use and syncs ...       5
# 4  It is a service that is not expected from such...       1
#
#                   date bank       source
# 0  2021-01-01 21:50:49  CBE  Google Play
# 1  2023-03-15 11:46:33  CBE  Google Play
# 2  2020-07-25 17:14:21  CBE  Google Play
# 3  2021-09-25 11:17:19  CBE  Google Play
# 4  2024-10-16 16:02:47  CBE  Google Play

# %%
df = df.drop_duplicates()

# %%
df['date'] = pd.to_datetime(df['date']).dt.strftime('%Y-%m-%d')

# %%
df = df.dropna()

# %%
df.to_csv('../data/processed_bank_reviews.csv', index=False)
print("Processed data saved to data/processed_bank_reviews.csv")
# Out:
# Processed data saved to data/processed_bank_reviews.csv
